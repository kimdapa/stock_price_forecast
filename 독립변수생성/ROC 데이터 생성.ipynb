# %% [markdown]
# # ROC (Rate of Charge)
#     ROC는 주식의 추세를 확인해 볼 수 있게 도와주는 관련 지표중 하나이다
#     공식은 다음과 같다 ((금일 종가 - N일 전 종가) / N일 전 종가) * 100
#     주가는 추세가 존재한다고 가정 즉, 오르는 주식은 계속 오르는 경향이 있고, 내리는 주식은 계속 내리는 경향이 있다고 가정할 때
#     ROC는 그러한 추세를 확인하는데 도움을 주는 지표이다. ROC가 0이상이면 상승추세 미만이면 하락 추세를 나타낸다
#     ROC의 단점은 횡보장에서는 별 영향을 끼치지 못한다는 점이다. 따라서 시황을 잘 보고 상황에 맞게 사용하는것이 좋다

# %%
import pandas as pd

df1 = pd.read_csv("./dataset/KODEX 200 2020 1 1 ~ 2020 6 1.csv", encoding='cp949')

# %% [markdown]
# #### row, column 확인

# %%
df1.shape
# Out:
# (101, 17)

# %% [markdown]
# #### 수치형 데이터들에 대한 분석
# mean과 50% 구간이 차이가 많이 난다면 이상치 문제를 고려해볼 수 있다

# %%
df1.describe()
# Out:
#                조회날짜      코드1            종가      전일대비 등락    전일대비 등락률  \
# count  1.010000e+02    101.0    101.000000   101.000000  101.000000
# mean   2.020031e+07  69500.0  26989.356436   -25.049505   -0.058713
# std    1.404157e+02      0.0   2686.742234   575.327513    2.397627
# min    2.020010e+07  69500.0  20240.000000 -1600.000000   -7.330000
# 25%    2.020021e+07  69500.0  25180.000000  -345.000000   -1.200000
# 50%    2.020032e+07  69500.0  26705.000000    55.000000    0.180000
# 75%    2.020042e+07  69500.0  29535.000000   290.000000    1.010000
# max    2.020053e+07  69500.0  31020.000000  1905.000000    9.290000
#
#                  시가            고가            저가     체결수량의 누적합  \
# count    101.000000    101.000000    101.000000  1.010000e+02
# mean   26990.841584  27270.396040  26687.623762  1.282583e+07
# std     2693.601220   2578.506708   2807.630281  9.544429e+06
# min    20230.000000  21020.000000  19945.000000  2.968338e+06
# 25%    25085.000000  25420.000000  24855.000000  6.612638e+06
# 50%    26605.000000  26870.000000  26300.000000  9.081063e+06
# 75%    29725.000000  29880.000000  29410.000000  1.487912e+07
# max    30935.000000  31135.000000  30850.000000  5.883334e+07
#
#        체결가격 * 체결수량 누적합       종가*상장좌수          상장좌수     기초지수 종가         순자산총액
# count     1.010000e+02  1.010000e+02  1.010000e+02  101.000000  1.010000e+02
# mean      3.293570e+11  6.834044e+12  2.507901e+08  266.863465  6.816202e+12
# std       2.078060e+11  1.627408e+12  3.948307e+07   26.600844  1.622378e+12
# min       8.850732e+10  4.980016e+12  1.892000e+08  199.280000  4.961423e+12
# 25%       1.939861e+11  5.346314e+12  2.241500e+08  249.400000  5.348175e+12
# 50%       2.565106e+11  6.050544e+12  2.456500e+08  263.740000  6.124754e+12
# 75%       3.811946e+11  8.245744e+12  2.718000e+08  292.020000  8.169393e+12
# max       1.212637e+12  9.814320e+12  3.271000e+08  306.080000  9.781775e+12

# %% [markdown]
# #### 결측치 검사

# %%
df1.isnull().sum()
# Out:
# 조회날짜               0
# 코드1                0
# 종목 코드              0
# 종목 명칭              0
# 종가                 0
# 전일대비 등락            0
# 전일대비 등락률           0
# 시가                 0
# 고가                 0
# 저가                 0
# 체결수량의 누적합          0
# 체결가격 * 체결수량 누적합    0
# 종가*상장좌수            0
# 상장좌수               0
# 기초지수 명칭            0
# 기초지수 종가            0
# 순자산총액              0
# dtype: int64

# %% [markdown]
# #### 데이터 샘플 확인

# %%
df1.head()
# Out:
#        조회날짜    코드1         종목 코드      종목 명칭     종가  전일대비 등락  전일대비 등락률     시가  \
# 0  20200529  69500  KR7069500007  KODEX 200  26775      -50     -0.19  26650
# 1  20200528  69500  KR7069500007  KODEX 200  26825       80      0.30  26940
# 2  20200527  69500  KR7069500007  KODEX 200  26745       15      0.06  26605
# 3  20200526  69500  KR7069500007  KODEX 200  26730      475      1.81  26295
# 4  20200525  69500  KR7069500007  KODEX 200  26255      325      1.25  26070
#
#       고가     저가  체결수량의 누적합  체결가격 * 체결수량 누적합        종가*상장좌수       상장좌수  \
# 0  26950  26520    8025387     214767801550  5127412500000  191500000
# 1  27110  26510   11259761     302448800590  5147717500000  191900000
# 2  26885  26555    9678327     258904588175  5114981250000  191250000
# 3  26730  26280    8550753     227638934175  5057316000000  189200000
# 4  26260  25885    7870015     205857149325  5077717000000  193400000
#
#    기초지수 명칭  기초지수 종가          순자산총액
# 0  코스피 200   268.32  5260021146651
# 1  코스피 200   268.29  5146663609010
# 2  코스피 200   267.64  5145057155373
# 3  코스피 200   267.31  5121475661890
# 4  코스피 200   262.76  4980286743861

# %% [markdown]
# #### 조회날짜를 index 및 datetime으로 변경

# %%
def make_datetime(x) :
    
    x = str(x)
    
    str_val = ''
    str_val += x[0:4] + "-"
    str_val += x[4:6] + "-"
    str_val += x[6:]
    
    return str_val

df1['조회날짜'] = pd.to_datetime(df1['조회날짜'].apply(make_datetime))
df1 = df1.set_index('조회날짜')

# %% [markdown]
# #### ROC를 계산하기 위해 n일전 데이터를 다루기 위한 map 선언 및 초기화

# %%
datetime_num_map = {}
num_datetime_map = {}

for num, index in enumerate(df1.index) :
    datetime_num_map[index] = num
    num_datetime_map[num] = index

# %% [markdown]
# #### 5월 1일부터 2월 1일까지를 계산하기 위해 데이터 초기화

# %%
df2 = df1.loc['2020-05-01':'2020-02-01']

# %% [markdown]
# #### 날짜 map을 바탕으로 n일전 데이터를 가져와 ROC 계산

# %%
now_day_list = []
roc_data_list = []

for index in df2.index :
    origin_index = datetime_num_map[index]
    
    # 현재 날짜
    now_day = index
    
    # 영업일 기준 14일 전 날짜
    prev_day = num_datetime_map[origin_index+14]
    
    # Rate of Charge = ((금일 종가 - 14일 전 종가) / 14일 전 종가) * 100
    now_price = df1.loc[now_day]['종가']
    prev_price = df1.loc[prev_day]['종가']
      
    roc = ((now_price - prev_price)/prev_price) * 100
    now_day_list.append(now_day)
    roc_data_list.append(roc)

# %% [markdown]
# #### 계산된 ROC를 바탕으로 새로운 데이터 프레임 정의

# %%
roc_df = pd.DataFrame(data = list(zip(now_day_list, roc_data_list)), columns = ['날짜', 'ROC'])
roc_df = roc_df.set_index('날짜')

# %%
roc_df
# Out:
#                  ROC
# 날짜
# 2020-04-29  5.130293
# 2020-04-28  2.908726
# 2020-04-27  5.623472
# 2020-04-24  7.690678
# 2020-04-23  9.044801
# ...              ...
# 2020-02-07 -1.630789
# 2020-02-06  0.214168
# 2020-02-05 -3.259089
# 2020-02-04 -3.274642
# 2020-02-03 -3.923525
#
# [62 rows x 1 columns]

# %% [markdown]
# #### 만들어진 roc_df를 csv로 출력

# %%
roc_df.to_csv("roc_data 2020 05 01 ~ 2020 02 01.csv", mode='w')

# %% [markdown]
# #### 잘 만들어졌는지 확인

# %%
df_test = pd.read_csv("roc_data 2020 05 01 ~ 2020 02 01.csv")

# %%
df_test.head()
# Out:
#            날짜       ROC
# 0  2020-04-29  5.130293
# 1  2020-04-28  2.908726
# 2  2020-04-27  5.623472
# 3  2020-04-24  7.690678
# 4  2020-04-23  9.044801
