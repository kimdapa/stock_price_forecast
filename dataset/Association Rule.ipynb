# %% [markdown]
# ### Association Rule (연관성 규칙)
# * 이번 시간에는 연관성 규칙을 통해서 로또번호에서 연관되어 있는 번호를 추출하고자 한다.

# %% [markdown]
# ### 1. 데이터 불러오기

# %%
# 학습 데이터 불러오기
import pandas as pd
data = pd.read_csv('lotto.csv')
display(data)
# Out:
#         회차   1   2   3   4   5   6  보너스
# 0     1014   3  11  14  18  26  27   21
# 1     1013  21  22  26  34  36  41   32
# 2     1012   5  11  18  20  35  45    3
# 3     1011   1   9  12  26  35  38   42
# 4     1010   9  12  15  25  34  36    3
# ...    ...  ..  ..  ..  ..  ..  ..  ...
# 1009     5  16  24  29  40  41  42    3
# 1010     4  14  27  30  31  40  42    2
# 1011     3  11  16  19  21  27  31   30
# 1012     2   9  13  21  25  32  42    2
# 1013     1  10  23  29  33  37  40   16
#
# [1014 rows x 8 columns]

# %%
data_as = pd.melt(data, id_vars=['회차'], value_vars=['1', '2', '3', '4', '5', '6', '보너스'])
data_as
# Out:
#         회차 variable  value
# 0     1014        1      3
# 1     1013        1     21
# 2     1012        1      5
# 3     1011        1      1
# 4     1010        1      9
# ...    ...      ...    ...
# 7093     5      보너스      3
# 7094     4      보너스      2
# 7095     3      보너스     30
# 7096     2      보너스      2
# 7097     1      보너스     16
#
# [7098 rows x 3 columns]

# %% [markdown]
# ### 2. 환경설정

# %% [markdown]
# * PyCaret에서 기계 학습 실험의 첫 번째 단계는 수행하고자 하는 작업에 맞는 필요한 모듈(arules)를 가져오고 환경을 설정하는 단계
# * 본 실습에서 연관성 규칙을 위해 사용하는 모듈은 pycaret.arules
# * setup() 함수를 통해 DataFrame의 데이터('data_as'), 거래ID변수('회차'), 아이템변수('value')를 정의하고 분류 모델을 초기화

# %%
from pycaret.arules import *

# %%
s = setup(data = data_as, transaction_id ='회차', item_id='value')
# Out:
# <style  type="text/css" >
# </style><table id="T_fceb6_" ><thead>    <tr>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_fceb6_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_fceb6_row0_col1" class="data row0 col1" >3911</td>
#             </tr>
#             <tr>
#                                 <td id="T_fceb6_row1_col0" class="data row1 col0" ># Transactions</td>
#                         <td id="T_fceb6_row1_col1" class="data row1 col1" >1014</td>
#             </tr>
#             <tr>
#                                 <td id="T_fceb6_row2_col0" class="data row2 col0" ># Items</td>
#                         <td id="T_fceb6_row2_col1" class="data row2 col1" >45</td>
#             </tr>
#             <tr>
#                                 <td id="T_fceb6_row3_col0" class="data row3 col0" >Ignore Items</td>
#                         <td id="T_fceb6_row3_col1" class="data row3 col1" >None</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### 3. 모델 생성

# %% [markdown]
# * 모델생성은 create_model함수를 바탕으로 이루어짐

# %%
model = create_model(metric='lift', threshold=1.2, min_support=0.03, max_len=3)

# %%
model
# Out:
#    antecedents consequents  antecedent support  consequent support  support  \
# 0         (25)         (2)              0.1460              0.1607   0.0325
# 1          (2)        (25)              0.1607              0.1460   0.0325
# 2          (3)        (20)              0.1578              0.1637   0.0345
# 3         (20)         (3)              0.1637              0.1578   0.0345
# 4         (21)        (11)              0.1568              0.1578   0.0325
# 5         (11)        (21)              0.1578              0.1568   0.0325
# 6         (12)        (24)              0.1647              0.1598   0.0335
# 7         (24)        (12)              0.1598              0.1647   0.0335
# 8          (7)        (18)              0.1558              0.1647   0.0325
# 9         (18)         (7)              0.1647              0.1558   0.0325
# 10        (20)         (4)              0.1637              0.1647   0.0335
# 11         (4)        (20)              0.1647              0.1637   0.0335
# 12        (13)         (3)              0.1686              0.1578   0.0325
# 13         (3)        (13)              0.1578              0.1686   0.0325
# 14        (10)        (31)              0.1598              0.1568   0.0306
# 15        (31)        (10)              0.1568              0.1598   0.0306
# 16        (13)        (39)              0.1686              0.1647   0.0335
# 17        (39)        (13)              0.1647              0.1686   0.0335
#
#     confidence    lift  leverage  conviction
# 0       0.2230  1.3871    0.0091      1.0801
# 1       0.2025  1.3871    0.0091      1.0708
# 2       0.2188  1.3362    0.0087      1.0705
# 3       0.2108  1.3362    0.0087      1.0672
# 4       0.2075  1.3153    0.0078      1.0628
# 5       0.2062  1.3153    0.0078      1.0623
# 6       0.2036  1.2743    0.0072      1.0550
# 7       0.2099  1.2743    0.0072      1.0572
# 8       0.2089  1.2682    0.0069      1.0558
# 9       0.1976  1.2682    0.0069      1.0521
# 10      0.2048  1.2436    0.0066      1.0505
# 11      0.2036  1.2436    0.0066      1.0501
# 12      0.1930  1.2230    0.0059      1.0436
# 13      0.2062  1.2230    0.0059      1.0474
# 14      0.1914  1.2204    0.0055      1.0427
# 15      0.1950  1.2204    0.0055      1.0437
# 16      0.1988  1.2073    0.0058      1.0426
# 17      0.2036  1.2073    0.0058      1.0439

# %%
pd.set_option('display.max_rows', None)
model
# Out:
#    antecedents consequents  antecedent support  consequent support  support  \
# 0         (25)         (2)              0.1460              0.1607   0.0325
# 1          (2)        (25)              0.1607              0.1460   0.0325
# 2          (3)        (20)              0.1578              0.1637   0.0345
# 3         (20)         (3)              0.1637              0.1578   0.0345
# 4         (21)        (11)              0.1568              0.1578   0.0325
# 5         (11)        (21)              0.1578              0.1568   0.0325
# 6         (12)        (24)              0.1647              0.1598   0.0335
# 7         (24)        (12)              0.1598              0.1647   0.0335
# 8          (7)        (18)              0.1558              0.1647   0.0325
# 9         (18)         (7)              0.1647              0.1558   0.0325
# 10        (20)         (4)              0.1637              0.1647   0.0335
# 11         (4)        (20)              0.1647              0.1637   0.0335
# 12        (13)         (3)              0.1686              0.1578   0.0325
# 13         (3)        (13)              0.1578              0.1686   0.0325
# 14        (10)        (31)              0.1598              0.1568   0.0306
# 15        (31)        (10)              0.1568              0.1598   0.0306
# 16        (13)        (39)              0.1686              0.1647   0.0335
# 17        (39)        (13)              0.1647              0.1686   0.0335
#
#     confidence    lift  leverage  conviction
# 0       0.2230  1.3871    0.0091      1.0801
# 1       0.2025  1.3871    0.0091      1.0708
# 2       0.2188  1.3362    0.0087      1.0705
# 3       0.2108  1.3362    0.0087      1.0672
# 4       0.2075  1.3153    0.0078      1.0628
# 5       0.2062  1.3153    0.0078      1.0623
# 6       0.2036  1.2743    0.0072      1.0550
# 7       0.2099  1.2743    0.0072      1.0572
# 8       0.2089  1.2682    0.0069      1.0558
# 9       0.1976  1.2682    0.0069      1.0521
# 10      0.2048  1.2436    0.0066      1.0505
# 11      0.2036  1.2436    0.0066      1.0501
# 12      0.1930  1.2230    0.0059      1.0436
# 13      0.2062  1.2230    0.0059      1.0474
# 14      0.1914  1.2204    0.0055      1.0427
# 15      0.1950  1.2204    0.0055      1.0437
# 16      0.1988  1.2073    0.0058      1.0426
# 17      0.2036  1.2073    0.0058      1.0439
